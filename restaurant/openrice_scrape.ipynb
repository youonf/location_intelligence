# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from tqdm import tqdm

# %%
url = "https://www.openrice.com/en/hongkong/restaurants"

headers = requests.utils.default_headers()
headers['User-Agent'] = 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 Safari/537.36'
response = requests.get(url, headers=headers)

# %%
response = response.text

# print(response)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-137-2e8a600dc6f0> in <module>()
# ----> 1 response = response.text
#       2
#       3 # print(response)
#
# AttributeError: 'str' object has no attribute 'text'

# %%
soup = BeautifulSoup(response, "html.parser")

# %%
soup.find_all(class_='title-name')[0].text.strip()
# Out:
# 'Shine'

# %%
soup.find_all(class_="counters-container")[0].text.strip()
# Out:
# '(931 Reviews)'

# %%
import re
review = soup.find_all(class_="counters-container")[0].text.strip()
int(*re.findall('\d+', review))
# Out:
# 931

# %%
soup.find_all(class_='icon-info-wrapper')[0].find('span').find(text=True).strip()
#https://stackoverflow.com/questions/53701062/extract-text-only-except-the-content-of-script-tag-from-html-with-beautifulsoup
# Out:
# '6/F, Prince Tower, 12A Peking Road,'

# %%
soup.find_all(class_='icon-info-wrapper')[0].find('a').text
# Out:
# 'Tsim Sha Tsui'

# %%
soup.find_all(class_="icon-info icon-info-food-name")[0].find_all('a')
# Out:
# [<a href="/en/hongkong/restaurants/cuisine/western">Western</a>,
#  <a href="/en/hongkong/restaurants/dish/wine">Wine</a>]

# %%
soup.find_all(class_="icon-info icon-info-food-name")[0].find_all('a')[0].text
# Out:
# 'Western'

# %%
soup.find_all(class_="icon-info icon-info-food-name")[0].find_all('a')[1].text
# Out:
# 'Wine'

# %%
soup.find_all(class_="text bookmarkedUserCount js-bookmark-count")[0]['data-count']
# Out:
# '26660'

# %%
soup.find_all(class_="emoticon-container smile-face pois-restaurant-list-cell-content-right-info-rating-happy")[0].text.strip()
# Out:
# '830'

# %%
soup.find_all(class_="emoticon-container sad-face pois-restaurant-list-cell-content-right-info-rating-sad")[0].text.strip()
# Out:
# '28'

# %%
import pandas as pd
from tqdm import tqdm

# %%
df = pd.DataFrame(columns =['name','review','bookmark','smile','sad','address','district','cuisine','dish'])
for i in tqdm(range(len(soup.find_all(class_='title-name')))):
    rest = {}
    rest['name'] = soup.find_all(class_='title-name')[i].text.strip()
    review = soup.find_all(class_="counters-container")[i].text.strip()
    rest['review'] = int(*re.findall('\d+', review))
    rest['bookmark'] = soup.find_all(class_="text bookmarkedUserCount js-bookmark-count")[i]['data-count']
    rest['smile'] = soup.find_all(class_="emoticon-container smile-face pois-restaurant-list-cell-content-right-info-rating-happy")[i].text.strip()
    rest['sad'] = soup.find_all(class_="emoticon-container sad-face pois-restaurant-list-cell-content-right-info-rating-sad")[i].text.strip()
    rest['address'] = soup.find_all(class_='icon-info-wrapper')[i].find('span').find(text=True).strip()
    rest['district'] = soup.find_all(class_='icon-info-wrapper')[i].find('a').text
    rest['cuisine'] = soup.find_all(class_="icon-info icon-info-food-name")[i].find_all('a')[0].text
    rest['dish'] = soup.find_all(class_="icon-info icon-info-food-name")[i].find_all('a')[1].text
    df = df.append(rest, ignore_index=True)
# Out:
# 100%|██████████| 15/15 [00:25<00:00,  1.66s/it]

# %%
df
# Out:
#                             name review bookmark smile sad  \
# 0                          Shine    931    26662   830  28
# 1                      Burgeroom   1116    42497   897  61
# 2   The Cheesecake Factory 芝樂坊餐廳    761    42448   459  47
# 3         CHEF STAGE de Eddy Chu    771    36535   690  20
# 4       LAB EAT Restaurant & Bar    620    57429   475  31
# 5                  Yadllie Plate    764    36297   581  36
# 6         Shika Teppan-Yaki 鉄人旨花    801    14083   761  10
# 7            The Captain's House    736    37516   594  28
# 8                      Burgeroom    635    18296   551  13
# 9    Day and Nite by Master Kama    709    33683   537  41
# 10                Love Cafe 心之食堂    657     9298   590  12
# 11                  Bingo & Cook    687    18846   600  13
# 12                        Espuma   1019    44756   654  81
# 13                 Sodam Chicken    832    28404   645  39
# 14                        Sky726    594    46823   442  41
#
#                                               address       district  \
# 0                 6/F, Prince Tower, 12A Peking Road,  Tsim Sha Tsui
# 1   Shop D, G/F, Food Street, 50-56 Paterson Stree...   Causeway Bay
# 2   Shop G102, G/F, Gateway Arcade, Harbour City, ...  Tsim Sha Tsui
# 3                            19/F, 17-19 Ashley Road,  Tsim Sha Tsui
# 4   Shop 1-2, G/F, Kiu Fung Mansion, 83-89 Kimberl...  Tsim Sha Tsui
# 5         11/F, CTMA Centre, 1 Sai Yeung Choi Street,       Mong Kok
# 6          2/F, Shining building, 477-481 Jaffe Road,   Causeway Bay
# 7                        18/F, H8, 8 Hau Fook Street,  Tsim Sha Tsui
# 8      Shop 207, L2, Mira Place One, 132 Nathan Road,  Tsim Sha Tsui
# 9                           1/F, 50 Shan Tung Street,       Mong Kok
# 10  Room 1203, 12/F, Bartlock Centre, 3 Yiu Wa Str...   Causeway Bay
# 11                2/F, L'Hart, 487-489 Lockhart Road,   Causeway Bay
# 12                        2/F, H8, 8 Hau Fook Street,  Tsim Sha Tsui
# 13             7/F, 3 Yiu Wa Street, Bartlock Centre,   Causeway Bay
# 14                         25/F, 724-726 Nathan Road,       Mong Kok
#
#      cuisine                  dish
# 0    Western                  Wine
# 1   American             Hamburger
# 2   American             Hamburger
# 3    Western                  Wine
# 4    Western               Seafood
# 5     Korean  Korean Fried Chicken
# 6   Japanese            Teppanyaki
# 7    Western               Seafood
# 8   American             Hamburger
# 9   Japanese               Seafood
# 10  Japanese         Sushi/Sashimi
# 11    Korean  Korean Fried Chicken
# 12   Spanish               Dessert
# 13    Korean  Korean Fried Chicken
# 14    French               Dessert

# %%
df = pd.DataFrame(columns =['name','review','bookmark','smile','sad','address','district','cuisine','dish'])

# %%
df = pd.DataFrame(columns =['name','review','bookmark','smile','sad','address','district','cuisine','dish'])

# %%
for j in tqdm(range(1,101)):
    url = "https://www.openrice.com/en/hongkong/restaurants"
    page = j
    headers = requests.utils.default_headers()
    headers['User-Agent'] = 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 Safari/537.36'
    response = requests.get(url+"?page="+str(j), headers=headers)
    response = response.text
    soup = BeautifulSoup(response, "html.parser")
    
    for i in range(len(soup.find_all(class_='title-name'))):
        rest = {}
        rest['name'] = soup.find_all(class_='title-name')[i].text.strip()
        review = soup.find_all(class_="counters-container")[i].text.strip()
        rest['review'] = int(*re.findall('\d+', review))
        rest['bookmark'] = soup.find_all(class_="text bookmarkedUserCount js-bookmark-count")[i]['data-count']
        rest['smile'] = soup.find_all(class_="emoticon-container smile-face pois-restaurant-list-cell-content-right-info-rating-happy")[i].text.strip()
        rest['sad'] = soup.find_all(class_="emoticon-container sad-face pois-restaurant-list-cell-content-right-info-rating-sad")[i].text.strip()
        rest['address'] = soup.find_all(class_='icon-info-wrapper')[i].find('span').find(text=True).strip()
        rest['district'] = soup.find_all(class_='icon-info-wrapper')[i].find('a').text
        rest['cuisine'] = soup.find_all(class_="icon-info icon-info-food-name")[i].find_all('a')[0].text
        rest['dish'] = soup.find_all(class_="icon-info icon-info-food-name")[i].find_all('a')[1].text
        df = df.append(rest, ignore_index=True)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-2d528a63649f> in <module>
#       6     response = requests.get(url+"?page="+str(j), headers=headers)
#       7     df = pd.DataFrame(columns =['name','review','bookmark','smile','sad','address','district','cuisine','dish'])
# ----> 8     for i in range(len(soup.find_all(class_='title-name'))):
#       9         rest = {}
#      10         rest['name'] = soup.find_all(class_='title-name')[i].text.strip()
#
# NameError: name 'soup' is not defined

# %%
df
# Out:
#                             name review bookmark smile sad  \
# 0                          Shine    931    26662   830  28
# 1                      Burgeroom   1116    42497   897  61
# 2   The Cheesecake Factory 芝樂坊餐廳    761    42448   459  47
# 3         CHEF STAGE de Eddy Chu    771    36535   690  20
# 4       LAB EAT Restaurant & Bar    620    57429   475  31
# 5                  Yadllie Plate    764    36297   581  36
# 6         Shika Teppan-Yaki 鉄人旨花    801    14083   761  10
# 7            The Captain's House    736    37516   594  28
# 8                      Burgeroom    635    18296   551  13
# 9    Day and Nite by Master Kama    709    33683   537  41
# 10                Love Cafe 心之食堂    657     9298   590  12
#
#                                               address       district  \
# 0                 6/F, Prince Tower, 12A Peking Road,  Tsim Sha Tsui
# 1   Shop D, G/F, Food Street, 50-56 Paterson Stree...   Causeway Bay
# 2   Shop G102, G/F, Gateway Arcade, Harbour City, ...  Tsim Sha Tsui
# 3                            19/F, 17-19 Ashley Road,  Tsim Sha Tsui
# 4   Shop 1-2, G/F, Kiu Fung Mansion, 83-89 Kimberl...  Tsim Sha Tsui
# 5         11/F, CTMA Centre, 1 Sai Yeung Choi Street,       Mong Kok
# 6          2/F, Shining building, 477-481 Jaffe Road,   Causeway Bay
# 7                        18/F, H8, 8 Hau Fook Street,  Tsim Sha Tsui
# 8      Shop 207, L2, Mira Place One, 132 Nathan Road,  Tsim Sha Tsui
# 9                           1/F, 50 Shan Tung Street,       Mong Kok
# 10  Room 1203, 12/F, Bartlock Centre, 3 Yiu Wa Str...   Causeway Bay
#
#      cuisine                  dish
# 0    Western                  Wine
# 1   American             Hamburger
# 2   American             Hamburger
# 3    Western                  Wine
# 4    Western               Seafood
# 5     Korean  Korean Fried Chicken
# 6   Japanese            Teppanyaki
# 7    Western               Seafood
# 8   American             Hamburger
# 9   Japanese               Seafood
# 10  Japanese         Sushi/Sashimi

# %%
page_df = pd.DataFrame()

# %%
for j in tqdm(range(1,4)):
    url = "https://www.openrice.com/en/hongkong/restaurants"
    page = j
    headers = requests.utils.default_headers()
    headers['User-Agent'] = 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 Safari/537.36'
    response = requests.get(url+"?page="+str(j), headers=headers)
    response = response.text
    page_df.append(response)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-f237edefa269> in <module>
#       6     response = requests.get(url+"?page="+str(j), headers=headers)
#       7     response = response.text
# ----> 8     page_df.append(response)
#
# ~/keras/lib/python3.6/site-packages/pandas/core/frame.py in append(self, other, ignore_index, verify_integrity, sort)
#    6690         return concat(to_concat, ignore_index=ignore_index,
#    6691                       verify_integrity=verify_integrity,
# -> 6692                       sort=sort)
#    6693
#    6694     def join(self, other, on=None, how='left', lsuffix='', rsuffix='',
#
# ~/keras/lib/python3.6/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     226                        keys=keys, levels=levels, names=names,
#     227                        verify_integrity=verify_integrity,
# --> 228                        copy=copy, sort=sort)
#     229     return op.get_result()
#     230
#
# ~/keras/lib/python3.6/site-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     287                        ' only pd.Series, pd.DataFrame, and pd.Panel'
#     288                        ' (deprecated) objs are valid'.format(type(obj)))
# --> 289                 raise TypeError(msg)
#     290
#     291             # consolidate
#
# TypeError: cannot concatenate object of type "<class 'str'>"; only pd.Series, pd.DataFrame, and pd.Panel (deprecated) objs are valid

# %%
df_text = pd.DataFrame(columns = ['page'])

# %%
a = 1
b = 2
c = 3

# %%
df_text.iloc[:-1,0] = 'abc'

# %%
df_text
# Out:
# Empty DataFrame
# Columns: [page]
# Index: []

# %%
with open('restaurant.csv','a') as f:
    f.write(response)

# %%
with open('restaurant.csv','r') as f:
    data = f.read()

# %%
data
# Out:
# '\n<!DOCTYPE html>\n<html lang="en-US" class="or-web">\n<head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb# website: http://ogp.me/ns/website#">\n        <meta charset="utf-8" />\n    <title>Hong Kong Restaurant Search  | OpenRice Hong Kong</title>\n    <meta name="theme-color" content="#ffcb05" />\n    <meta name="viewport" content="width=1280" />\n            <link rel="dns-prefetch" href="//static5.orstatic.com">\n            <link rel="dns-prefetch" href="//static6.orstatic.com">\n            <link rel="dns-prefetch" href="//static7.orstatic.com">\n            <link rel="dns-prefetch" href="//static8.orstatic.com">\n                        <meta property="og:title" content="Hong Kong Restaurant Search  | OpenRice Hong Kong">\n                        <meta property="og:url" content="https://www.openrice.com/en/hongkong/restaurants?page=1">\n                        <meta property="og:description" content="Find Food &amp; Dining places in Hong Kong at OpenRice Hong Kong">\n                        <meta property="og:type" content="website">\n                        <meta property="fb:app_id" content="156354557765535">\n                        <meta name="description" content="Find Food &amp; Dining places in Hong Kong at OpenRice Hong Kong">\n        <link rel="canonical" href="https://www.openrice.com/en/hongkong/restaurants?page=1">\n            <link rel="alternate" href="https://www.openrice.com/zh/hongkong/restaurants?page=1" hreflang="zh-HK">\n            <link rel="alternate" href="https://www.openrice.com/zh/hongkong/restaurants?page=1" hreflang="zh">\n            <link rel="alternate" href="https://www.openrice.com/zh-cn/hongkong/restaurants?page=1" hreflang="zh-CN">\n            <link rel="alternate" href="https://www.openrice.com/en/hongkong/restaurants?page=1" hreflang="en-US">\n            <link rel="alternate" href="https://www.openrice.com/en/hongkong/restaurants?page=1" hreflang="en">\n            <link rel="alternate" href="https://www.openrice.com/en/hongkong/restaurants?page=1" hreflang="x-default">\n    <link rel="manifest" href="/public/manifest.json">\n    <link rel="shortcut icon" href="/favicon.ico" type="image/x-icon" />\n    <link rel="search" type="application/opensearchdescription+xml" title="OpenRice.com" href="/OpenRiceSearchProvider">\n\n        <link href=\'https://fonts.googleapis.com/css?family=Lato:400,700\' rel=\'stylesheet\' type=\'text/css\'>\n                <style type="text/css">\n                    @import url(https://fonts.googleapis.com/earlyaccess/notosanstc.css);\n                </style>\n<link href="//static5.orstatic.com/bundles/css/v/common.YWSN7i2wo1AOjlG0x_s5nEr1_gz5_Q2PLC-e-OcuAcM1-v580.css" rel="stylesheet"/>\n<link href="//static8.orstatic.com/bundles/css/v/or/search.j4MTWX0kDa3Kr1e8bozaV_CoYS65axlh669PUyQ3EjM1-v580.css" rel="stylesheet"/>\n<link href="//static8.orstatic.com/bundles/css/v/or/booking-picker.DvYSFMEVoxGVOhsFAg06mF26SxYLddk35aynGALOL-k1-v580.css" rel="stylesheet"/>\n\n    <link href="//static7.orstatic.com/bundles/css/v/or/promotion.KMEEIuIzXBJ8S9Bwh2SV-VDwQM2xTus2qrp07Hqts3E1-v580.css" rel="stylesheet"/>\n\n    <link href="//static5.orstatic.com/bundles/css/v/or/booking.Q7QqxYkmb8IYfwCk6bynZ-TRW_16LNNc9llvYt7P6P01-v580.css" rel="stylesheet"/>\n\n    <link href="//static6.orstatic.com/bundles/css/v/or/poi-list.oxnYWvgOQCuC9lFfOtPEA_K6-JaNVokRyBwHyV_CU7I1-v580.css" rel="stylesheet"/>\n\n\n    <script src="//static8.orstatic.com/bundles/js/v/jquery.adXX0-nm_2oM-hG3-HEc217tE9nteWTgGv0sEo7ak3o1-v580.js"></script>\n\n        <script id="googleTagCustomTargetingScript" type="text/javascript" data-target="{&quot;language&quot;:[&quot;en&quot;],&quot;region&quot;:[&quot;0&quot;]}">\n        var googletag = googletag || {};\n        googletag.cmd = googletag.cmd || [];\n        (function () {\n            var gads = document.createElement("script");\n            gads.async = true;\n            gads.type = "text/javascript";\n            var useSSL = "https:" ...

# %%
len(data)
# Out:
# 2320206

# %%
len(response)
# Out:
# 1180396
